# %%
import pandas as pd
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
import numpy as np

import pymysql
pymysql.install_as_MySQLdb()

import warnings
warnings.simplefilter('ignore', FutureWarning)

# %%
HR_Data = "HR_Mockdata.xlsx"
HR_Data_df = pd.read_excel(HR_Data, index_col=None)
HR_Data_df.head(2)
# Out:
#       #  satisfaction_level  last_evaluation  number_project  \
# 0  4980                0.67             0.36               4
# 1  6302                0.84             0.56               5
#
#    average_montly_hours  time_spend_company  Work_accident  left  \
# 0                   130                   4              0     0
# 1                   130                   6              0     0
#
#    promotion_last_5years sales \nfunction    ...            leader_host  \
# 0                      0            sales    ...          poor perfomer
# 1                      0        technical    ...     well placed talent
#
#   country_home  culture_home   country_host culture_host function_host  \
# 0    australia   egalitarian  united states  egalitarian       medical
# 1        italy  hierarquical  united states  egalitarian       finance
#
#   business Size_host economic Perspective_host fired_quit buzz_bust
# 0      united states                  positive       quit      bust
# ...

# %%
HR_Data_df.keys()
# Out:
# Index(['#', 'satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'sales \nfunction', 'salary', 'hire_date',
#        'move_date', 'end_date', 'leader_host', 'country_home', 'culture_home',
#        'country_host', 'culture_host', 'function_host', 'business Size_host',
#        'economic Perspective_host', 'fired_quit', 'buzz_bust'],
#       dtype='object')

# %%
database = {
    'user': 'p3', 
    'password': 'project3',
    'port': '3306',
    'host': 'localhost',
    'database': 'project3',
    'dialect': 'mysql',
    'driver': None
}

# %%
db_prefix = database['dialect']
if database['driver'] is not None:
    db_prefix += database['driver']

# %%
DATABASE_URL = f"{db_prefix}://{database['user']}:{database['password']}@{database['host']}:{database['port']}/{database['database']}"

# %%
engine = create_engine(DATABASE_URL)

# %%
engine.table_names()
# Out:
# []

# %%
HR_Data_df.to_sql(name='test', con=engine, if_exists='append',index=False)

# %%
engine.table_names()
# Out:
# ['test']

# %%
df = pd.read_sql('SELECT * FROM test', con=engine)
df
# Out:
#            #  satisfaction_level  last_evaluation  number_project  \
# 0       4980                0.67             0.36               4
# 1       6302                0.84             0.56               5
# 2       9513                0.47             0.57               3
# 3       7040                0.81             0.45               6
# 4       8086                0.33             0.39               3
# 5       9167                0.84             0.55               6
# 6       9499                0.50             0.57               5
# 7       9516                0.54             0.46               2
# 8       9822                0.61             0.99               5
# 9      10572                0.15             0.91               6
# 10     13021                0.51             0.74               6
# 11      2476                0.32             0.42               2
# 12      6323                0.26             0.39               3
# ...

# %%
hostIP = "localhost"
userName = "p3"
userPassword = "project3"
database = "project3"

# %%
con = pymysql.connect(host=hostIP,
                        user=userName,
                        password=userPassword,
                        db=database,
                        autocommit=True)

# %%
cursorObject = con.cursor()

# %%
alter_test = "ALTER TABLE test ADD TableID int NOT NULL AUTO_INCREMENT PRIMARY KEY;"

# %%
cursorObject.execute(alter_test)
# Out:
# 0

# %%
alter_test2 = "ALTER TABLE test MODIFY hire_date DATETIME;"

# %%
cursorObject.execute(alter_test2)
# Out:
# 14999

# %%
describe_test = "DESC test"

# %%
cursorObject.execute(describe_test)
# Out:
# 25

# %%
columns = cursorObject.fetchall()

# %%
for column in columns:
    print(column)
# Out:
# ('#', 'bigint(20)', 'YES', '', None, '')
# ('satisfaction_level', 'double', 'YES', '', None, '')
# ('last_evaluation', 'double', 'YES', '', None, '')
# ('number_project', 'bigint(20)', 'YES', '', None, '')
# ('average_montly_hours', 'bigint(20)', 'YES', '', None, '')
# ('time_spend_company', 'bigint(20)', 'YES', '', None, '')
# ('Work_accident', 'bigint(20)', 'YES', '', None, '')
# ('left', 'bigint(20)', 'YES', '', None, '')
# ('promotion_last_5years', 'bigint(20)', 'YES', '', None, '')
# ('sales \nfunction', 'text', 'YES', '', None, '')
# ('salary', 'text', 'YES', '', None, '')
# ('hire_date', 'text', 'YES', '', None, '')
# ('move_date', 'text', 'YES', '', None, '')
# ('end_date', 'text', 'YES', '', None, '')
# ('leader_host', 'text', 'YES', '', None, '')
# ('country_home', 'text', 'YES', '', None, '')
# ('culture_home', 'text', 'YES', '', None, '')
# ('country_host', 'text', 'YES', '', None, '')
# ('culture_host', 'text', 'YES', '', None, '')
# ...
